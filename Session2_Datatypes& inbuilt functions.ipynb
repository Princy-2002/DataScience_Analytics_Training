# %% [markdown]
# **LIST** - []    we assign values in square brackets

# %%
groceries = []
type(groceries)
# Out:
# list

# %%
groceries = ["Apples","banana","pen","bread","bag"]
print(groceries)
# Out:
# ['Apples', 'banana', 'pen', 'bread', 'bag']

# %%
My_name ="Princy Prabhakar"
my_age =24
my_cgpa= 7.19
Graduation_year = 2024
Details = [My_name,my_age,my_cgpa,Graduation_year]
print(Details)
# Out:
# ['Princy Prabhakar', 24, 7.19, 2024]

# %%
print(f"My name is {My_name} I have {my_age} years old.I have {my_cgpa}cgpa. My Graduation year is {Graduation_year}")
# Out:
# My name is Princy Prabhakar I have 24 years old.I have 7.19cgpa. My Graduation year is 2024

# %%
Details.append("Ktu")         #append is used to add anything in the last of a list,here i added ktu in last of the list Details
Details
# Out:
# ['Princy Prabhakar', 24, 7.19, 2024, 'Ktu']

# %%
Details.extend(["python","Data analytics"])
print(Details)
# Out:
# ['Princy Prabhakar', 24, 7.19, 2024, 'Ktu', 'python', 'Data analytics']

# %%
Details.insert(1, "Female")

print(Details)
# Out:
# ['Princy Prabhakar', 'Female', 24, 7.19, 2024, 'Ktu', 'python', 'Data analytics']

# %%
Details.remove(7.19)

print(Details)
# Out:
# ['Princy Prabhakar', 'Female', 24, 2024, 'Ktu', 'python', 'Data analytics']

# %%
Details.pop(2)

print(Details)
# Out:
# ['Princy Prabhakar', 'Female', 2024, 'Ktu', 'python', 'Data analytics']

# %%
Details.reverse()

print(Details)
# Out:
# ['Data analytics', 'python', 'Ktu', 2024, 'Female', 'Princy Prabhakar']

# %%
New_details = Details.copy()

print(New_details)
# Out:
# ['Data analytics', 'python', 'Ktu', 2024, 'Female', 'Princy Prabhakar']

# %%
numbers = [1, 2, 1, 1, 3]

print(numbers.count(1))
# Out:
# 3

# %% [markdown]
# **Tuple**

# %%
items=()
type(items)
# Out:
# tuple

# %%
items=("lekz",7.8,"Eligible")
items
# Out:
# ('lekz', 7.8, 'Eligible')

# %%
items[1]
# Out:
# 8.5

# %%
items_list = list(items)     #here i need to change the value in 1st index,so i change the tuple into list
items_list
# Out:
# ['lekz', 7.8, 'Eligible']

# %%
items_list[1] =8.5    #here i changed the value by make the tuple as list
items_list
# Out:
# ['lekz', 8.5, 'Eligible']

# %%
items=tuple(items_list)  #here i again changed back to tuple
items
# Out:
# ('lekz', 8.5, 'Eligible')

# %%
name=items[0]      #HERE i assigned value based on index - it is a method
score=items[1]
eligibility=items[2]
print(name,score,eligibility)
# Out:
# lekz 8.5 Eligible

# %%
name,sc,eligible= items    #here is the another method of assigning
print(name,sc,eligible)
# Out:
# lekz 8.5 Eligible

# %%
marks=(43,47,45)     #here i concatinate two section-one is in items,other is in marks
details=(items+marks)
details
# Out:
# ('lekz', 8.5, 'Eligible', 43, 47, 45)

# %%
print("Eligible" in details)
# Out:
# True

# %% [markdown]
# **Dictionary**

# %%
Movie={
    'title': 'Drishyam3',
    'released_year':'2026',
    'Genre' : 'thriller',
     'rating': 8.5,
    'cast' : ['mohanlal','meena','esther','ansiba'],
    'storyline' : 'A cable tv operator tries to protect his family'
}
print(Movie)
# Out:
# {'title': 'Drishyam3', 'released_year': '2026', 'Genre': 'thriller', 'rating': 8.5, 'cast': ['mohanlal', 'meena', 'esther', 'ansiba'], 'storyline': 'A cable tv operator tries to protect his family'}

# %%
print(f"{Movie['title']}({Movie['released_year']})")
print(Movie['Genre'])
print(Movie['rating'])
print(",".join(Movie['cast']))
print(f"{Movie['storyline'][:30]}...")
# Out:
# Drishyam3(2026)
# thriller
# 8.5
# mohanlal,meena,esther,ansiba
# A cable tv operator tries to p...

# %%
Movie['Director']='Jeethu joseph'
print(Movie['Director'])
# Out:
# Jeethu joseph

# %%
Movie.update({'language':'Malayalam','Genre': 'Family'})    #update function
Movie
# Out:
# {'title': 'Drishyam3',
#  'released_year': '2026',
#  'Genre': 'Family',
#  'rating': 8.5,
#  'cast': ['mohanlal', 'meena', 'esther', 'ansiba'],
#  'storyline': 'A cable tv operator tries to protect his family',
#  'Director': 'Jeethu joseph',
#  'language': 'Malayalam',
#  'genre': 'Family'}

# %%
Movie.keys()
# Out:
# dict_keys(['title', 'released_year', 'Genre', 'rating', 'cast', 'storyline', 'Director', 'language', 'genre'])

# %%
Movie.values()
# Out:
# dict_values(['Drishyam3', '2026', 'thriller', 8.5, ['mohanlal', 'meena', 'esther', 'ansiba'], 'A cable tv operator tries to protect his family', 'Jeethu joseph', 'Malayalam', 'Family'])

# %%
print(Movie.get('title'))    #get a particular function
# Out:
# Drishyam3

# %%
print(Movie ['genre'])
# Out:
# Family

# %%
Movie.pop("language")

print(Movie)
# Out:
# {'title': 'Drishyam3', 'released_year': '2026', 'Genre': 'Family', 'rating': 8.5, 'cast': ['mohanlal', 'meena', 'esther', 'ansiba'], 'storyline': 'A cable tv operator tries to protect his family', 'Director': 'Jeethu joseph', 'genre': 'Family'}

# %%
print(Movie["cast"][2])
# Out:
# esther

# %%
Movie["rating"] = 9.5

print(Movie)
# Out:
# {'title': 'Drishyam3', 'released_year': '2026', 'Genre': 'Family', 'rating': 9.5, 'cast': ['mohanlal', 'meena', 'esther', 'ansiba'], 'storyline': 'A cable tv operator tries to protect his family', 'Director': 'Jeethu joseph', 'genre': 'Family'}

# %%
netflix_movies={
    "Drishyam3" : {
         'released_year': '2026',
 'Genre': 'Family',
 'rating': 8.5,
 'cast': ['mohanlal', 'meena', 'esther', 'ansiba'],
 'storyline': 'A cable tv operator tries to protect his family',
 'Director': 'Jeethu joseph',
 'language': 'Malayalam',
 'genre': 'Family'},

 'Vazha2' : {
     'released_year': '2026',
 'Genre': 'Family',
 'rating': 8.5,
 'cast': ['Hashir', 'Alan', 'Vinayak', 'Ajin'],
 'storyline': 'Friends life story',
 'language': 'Malayalam'
 },

 'patriot' : {
    'released_year': '2026',
 'Genre': 'Family',
 'rating': 9.5,
 'cast': ['Mohanlal', 'Mammootty', 'Nayanthara', 'Kunjacko'],
 'storyline': 'Nation related',
 'language': 'Malayalam'
}
}

# %%
print(netflix_movies['Vazha2']['cast'])
# Out:
# ['Hashir', 'Alan', 'Vinayak', 'Ajin']

# %%
print(netflix_movies['patriot']['rating'])
# Out:
# 9.5

# %%
print(netflix_movies['patriot'] ['language'])
# Out:
# Malayalam
