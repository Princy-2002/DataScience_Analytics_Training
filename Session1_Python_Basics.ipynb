# %%
print("Welcome to python session")
# Out:
# Welcome to python session

# %%
print('Good to see you')
# Out:
# Good to see you

# %%
print(30)
# Out:
# 30

# %%
print(4.5)
# Out:
# 4.5

# %%
print("Princy","Lekshmi","Deepika")
# Out:
# Princy Lekshmi Deepika

# %%
print("Princy","Lekshmi","Deepika",sep="_")    #sep=("_") is for underscore in output
# Out:
# Princy_Lekshmi_Deepika

# %%
age=(24)
print(age)
# Out:
# 24

# %%
name="Princy"
age=24
university="KTU"
cgpa=7.19
place="mavelikara"
Height=152
print(name,age,university,cgpa,place,Height,sep=",")
# Out:
# Princy,24,KTU,7.19,mavelikara,152

# %%
print("I am",name,"I graduated in",university,"I have",cgpa,"my height is",Height,sep=",")
# Out:
# I am,Princy,I graduated in,KTU,I have,7.19,my height is,152

# %%
print(f"I am {name}I graduated in {university}with {cgpa} I have{age}my Height is{Height}")   #print(f "I can define with I am,I have in one stretch"
# Out:
# I am PrincyI graduated in KTUwith 7.19 I have24my Height is152

# %%
input("Enter your name")
print(f"Hello {name}!!!")          #input is use for textbox
# Out:
# Enter your nameMaya
# Hello Princy!!!

# %%
Place="Chayakkada"
thing="cardamom cappuchino"
Name="Maya"

print(f"Fetching a 2 cups {thing} for {Name}")
print(f"Enjoy your beverage,and thanks for stopping by {Place}")
# Out:
# Fetching a 2 cups cardamom cappuchino for Maya
# Enjoy your beverage,and thanks for stopping by Chayakkada

# %%
cgpa= input("Enter your cgpa")
print(f"Your cgpa is {cgpa}")
# Out:
# Enter your cgpa7.19
# Your cgpa is 7.19

# %%
type(cgpa)     #If add input,it is always in string type,it can't change later or done any operations.so we define the type of input by add float if it is floating value
               # add int,if it is integer value before input
# Out:
# str

# %% [markdown]
# #If add input,it is always in string type,it can't change later or done any operations.so we define the type of input by add **float** if it is floating value and add **int**,if it is integer value before input

# %%
cgpa= float(input("Enter your cgpa"))
print(f"Your cgpa is {cgpa}")
type(cgpa)
# Out:
# Enter your cgpa7.19
# Your cgpa is 7.19
# float

# %%
text=" Welcome to Python Programming! "
len(text)
# Out:
# 32

# %%
text[0]      #First letter
# Out:
# 'W'

# %%
text[-1]    #last letter,here last letter
# Out:
# '!'

# %%
text[0:13]     #0 is the start position letter of the sentence and 13 is the limited we applied
# Out:
# 'Welcome to Py'

# %%
text[13:]  #here i didn't mention end position,so it automatically apply from 25th position to last position
# Out:
# 'thon Programming!'

# %%
text[:10]    #here i didn't mention first position,so it automatically apply from start position to the limit I applied"25th" position
# Out:
# 'Welcome to'

# %%
text.split()                                    #if we applied the function split,it will provide the output as list,
                                               #through this we can find out the how many words include in it
# Out:
# ['Welcome', 'to', 'Python', 'Programming!']

# %%
text.strip()   #we use strip function to avoid spaces from beginning and end
# Out:
# 30

# %%
text.lower()      # use lower forconvert the letters into small letters
# Out:
# ' welcome to python programming! '

# %%
text.find("Python")   #find a position of particular word
# Out:
# 12

# %%
text.replace("Python","Java")  #here i replace python as java
# Out:
# ' Welcome to Java Programming! '

# %%
text.partition("Python")     #it is used to partition each word
# Out:
# (' Welcome to ', 'Python', ' Programming! ')

# %%
text.endswith("to")    #it is used for checking applications,if i need to collect some files end with pdf,so here i can use this
# Out:
# False

# %% [markdown]
# **OPERATORS**

# %%
text
# Out:
# ' Welcome to Python Programming! '

# %%
print("Python" in text)    #to check a particular word is available or not    #here i used the function "in"
# Out:
# True

# %%
print("java" not in text)   #to check java is not available in the sentence   #here i used the function "not in"
# Out:
# True

# %%
jan_sales= 20000
feb_sales= 30000
dec_sales= 56000
sep_sales= 70000
average=(20000+30000+56000+70000)/4
print(average)
# Out:
# 44000.0

# %%
fuel_price = 100
friends= 4
km_per_litre = 15
distance = 300
toll_cost = 500
food_cost =1300
budget = 1000


fuel_needed= 300/15
fuel_cost = (fuel_needed* 100)
print(fuel_cost)
total_trip_cost = (fuel_cost+food_cost+ toll_cost)
cost_per_person = ((food_cost/4)+(toll_cost/4)+(fuel_cost/4))
print(total_trip_cost)
print(cost_per_person)
print(f"fuel_cost is {fuel_cost}"),
print(f"Total_trip_cost is {total_trip_cost}"),
print(f"cost_per_person is {cost_per_person}")
# Out:
# 2000.0
# 3800.0
# 950.0
# fuel_cost is 2000.0
# Total_trip_cost is 3800.0
# cost_per_person is 950.0
